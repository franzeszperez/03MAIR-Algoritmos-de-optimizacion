# %% [markdown]
# <a href="https://colab.research.google.com/github/franzeszperez/03MAIR-Algoritmos-de-optimizacion/blob/master/AG1/Sort_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install sorting
# Out:
# ...
#   Stored in directory: /root/.cache/pip/wheels/1d/69/7d/afb45b857f9cd6d7927312839c0928f20284f476cb4265474e
# Successfully built sorting
# ...

# %%
import sorting

lista = [34, 540, 5, 21, 22, 19, 541.4, 539.99]
lista_ordenada = sorting.bubble(lista)
print(lista_ordenada)
# Out:
# [5, 19, 21, 22, 34, 539.99, 540, 541.4]
